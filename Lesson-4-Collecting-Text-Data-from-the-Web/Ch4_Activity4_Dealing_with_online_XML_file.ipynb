# %% [markdown]
# # Activity 4: Dealing with online XML file

# %% [markdown]
# Search for Harry Potter in goodreads and print top Book Names,	Authors and their Average Rating

# %% [markdown]
# Sign up from https://www.goodreads.com/user/new?remember=true <br>
# Get access key by filling in the form available at https://www.goodreads.com/api/keys

# %%
key = 'ABCxyzzzzzzzqqqqq' #Your secret key over here

# %%
import urllib3
from pprint import pprint
import xml.etree.ElementTree as ET
import pandas as pd

# %%
http = urllib3.PoolManager()
rrq = http.request('GET', 'https://www.goodreads.com/search.xml', fields={"key":key,"q":"Harry Potter"})
#q represents the querry we want to search for

rrq.status
# Out:
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200

# %%
tree = ET.fromstring(rrq.data)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(rrq.data, 'lxml')

# %%
pprint(soup)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><goodreadsresponse>
# <request>
# <authentication>true</authentication>
# <key></key>
# <method></method>
# </request>
# <search>
# <query></query>
# <results-start>1</results-start>
# <results-end>18</results-end>
# <total-results>3730</total-results>
# <source>Goodreads</source>
# <query-time-seconds>0.19</query-time-seconds>
# <results>
# <work>
# <id type="integer">4640799</id>
# <books_count type="integer">233</books_count>
# <ratings_count type="integer">5812151</ratings_count>
# <text_reviews_count type="integer">93300</text_reviews_count>
# <original_publication_year type="integer">1997</original_publication_year>
# <original_publication_month type="integer">6</original_publication_month>
# <original_publication_day type="integer">26</original_publication_day>
# <average_rating>4.46</average_rating>
# <best_book type="Book">
# <id type="integer">3</id>
# <title>Harry Potter and the Sorcerer's Stone (Harry Potter, #1)</title>
# ...

# %%
df = pd.DataFrame([(title.text.strip(),author.text.strip(),rating.text.strip())\
                   for title,author,rating in zip(soup.find_all('title'), \
                                                  soup.find_all('name'), soup.find_all('average_rating'))])
df.columns = ['Book Name', 'Author', 'Average Rating']
df
# Out:
#                                             Book Name             Author  \
# 0   Harry Potter and the Sorcerer's Stone (Harry P...       J.K. Rowling
# 1   Harry Potter and the Prisoner of Azkaban (Harr...       J.K. Rowling
# 2   Harry Potter and the Chamber of Secrets (Harry...       J.K. Rowling
# 3   Harry Potter and the Goblet of Fire (Harry Pot...       J.K. Rowling
# 4   Harry Potter and the Order of the Phoenix (Har...       J.K. Rowling
# 5   Harry Potter and the Half-Blood Prince (Harry ...       J.K. Rowling
# 6   Harry Potter and the Cursed Child: Parts One a...       John Tiffany
# 7   Harry Potter and the Deathly Hallows (Harry Po...       J.K. Rowling
# 8    Harry Potter Series Box Set (Harry Potter, #1-7)       J.K. Rowling
# 9      Harry Potter: The Prequel (Harry Potter, #0.5)       J.K. Rowling
# 10       Harry Potter Collection (Harry Potter, #1-6)       J.K. Rowling
# 11                        Harry Potter: Film Wizardry       Brian Sibley
# ...
