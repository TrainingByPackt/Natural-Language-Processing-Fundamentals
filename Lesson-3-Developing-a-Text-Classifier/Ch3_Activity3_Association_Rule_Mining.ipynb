# %% [markdown]
# # Activity 3 : Association Rule Mining
# Extract frequent itemsets and association rules countrywise from the transactional data: https://archive.ics.uci.edu/ml/datasets/online+retail

# %%
#!pip install mlxtend

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori

# %%
#Dataset citation: Daqing Chen, Sai Liang Sain, and Kun Guo, Data mining for the online retail industry:
#A case study of RFM model-based customer segmentation using data mining, Journal of Database Marketing and 
#Customer Strategy Management, Vol. 19, No. 3, pp. 197â€“208, 2012 
#(Published online before print: 27 August 2012. doi: 10.1057/dbm.2012.17).
#Url: https://archive.ics.uci.edu/ml/datasets/online+retail#

# %%
transaction_df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
transaction_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
transaction_df.shape
# Out:
# (541909, 8)

# %%
transaction_df['Description'].value_counts()[:100]
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
# ASSORTED COLOUR BIRD ORNAMENT          1501
# SET OF 3 CAKE TINS PANTRY DESIGN       1473
# PACK OF 72 RETROSPOT CAKE CASES        1385
# LUNCH BAG  BLACK SKULL.                1350
# NATURAL SLATE HEART CHALKBOARD         1280
# POSTAGE                                1252
# JUMBO BAG PINK POLKADOT                1251
# HEART OF WICKER SMALL                  1237
# JAM MAKING SET WITH JARS               1229
# JUMBO STORAGE BAG SUKI                 1214
# PAPER CHAIN KIT 50'S CHRISTMAS         1210
# JUMBO SHOPPER VINTAGE RED PAISLEY      1202
# LUNCH BAG CARS BLUE                    1197
# LUNCH BAG SPACEBOY DESIGN              1192
# JAM MAKING SET PRINTED                 1182
# RECIPE BOX PANTRY YELLOW DESIGN        1180
# SPOTTY BUNTING                         1172
# LUNCH BAG SUKI DESIGN                  1139
# ROSES REGENCY TEACUP AND SAUCER        1138
# LUNCH BAG PINK POLKADOT                1137
# WOODEN PICTURE FRAME WHITE FINISH      1129
# SET OF 4 PANTRY JELLY MOULDS           1111
# ALARM CLOCK BAKELIKE RED               1107
# GREEN REGENCY TEACUP AND SAUCER        1085
# LUNCH BAG APPLE DESIGN                 1084
#                                        ...
# SCOTTIE DOG HOT WATER BOTTLE            798
# CLOTHES PEGS RETROSPOT PACK 24          792
# LUNCH BAG ALPHABET DESIGN               780
# GARDENERS KNEELING PAD CUP OF TEA       780
# CHARLOTTE BAG PINK POLKADOT             777
# GIN + TONIC DIET METAL SIGN             775
# RED HANGING HEART T-LIGHT HOLDER        773
# STRAWBERRY CERAMIC TRINKET BOX          770
# HANGING HEART JAR T-LIGHT HOLDER        767
# ROUND SNACK BOXES SET OF4 WOODLAND      764
# RECYCLING BAG RETROSPOT                 760
# LUNCH BOX I LOVE LONDON                 750
# COOK WITH WINE METAL SIGN               745
# STRAWBERRY CHARLOTTE BAG                742
# DOORMAT KEEP CALM AND COME IN           742
# IVORY KITCHEN SCALES                    741
# JUMBO BAG 50'S CHRISTMAS                739
# JUMBO BAG VINTAGE DOILY                 737
# PLASTERS IN TIN WOODLAND ANIMALS        729
# GUMBALL COAT RACK                       728
# JUMBO STORAGE BAG SKULLS                720
# ANTIQUE SILVER T-LIGHT GLASS            719
# PACK OF 20 NAPKINS PANTRY DESIGN        709
# DOTCOM POSTAGE                          709
# SET OF 3 BUTTERFLY COOKIE CUTTERS       707
# DOORMAT RED RETROSPOT                   707
# LUNCH BAG DOLLY GIRL DESIGN             706
# JUMBO BAG SPACEBOY DESIGN               702
# SET OF 3 HEART COOKIE CUTTERS           700
# WOOD BLACK BOARD ANT WHITE FINISH       698
# Name: Description, Length: 100, dtype: int64

# %%
transaction_df_small = transaction_df[transaction_df['Description']\
                            .isin(transaction_df['Description'].value_counts()[:100].reset_index()['index'])]

# %%
transaction_df_small.shape
# Out:
# (99739, 8)

# %%
transaction_df_small['Country'].value_counts()
# Out:
# United Kingdom          90086
# Germany                  2082
# France                   2068
# EIRE                     1492
# Belgium                   571
# Netherlands               531
# Spain                     484
# Portugal                  339
# Switzerland               338
# Australia                 280
# Norway                    179
# Italy                     174
# Channel Islands           161
# Finland                   138
# Sweden                    103
# Denmark                    84
# Cyprus                     83
# Austria                    72
# Poland                     66
# Israel                     55
# Unspecified                47
# Hong Kong                  38
# Singapore                  38
# Japan                      37
# Iceland                    34
# USA                        28
# Greece                     25
# Canada                     19
# RSA                        19
# Malta                      17
# United Arab Emirates       13
# Brazil                     12
# Lebanon                     9
# European Community          9
# Bahrain                     4
# Czech Republic              3
# Lithuania                   1
# Name: Country, dtype: int64

# %%
dataset = [[str(itm) for itm in trans] for trans in list(transaction_df_small.groupby('Country')\
                                         .agg({'Description' : lambda x: set(x)}).reset_index()['Description'])]
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(df, min_support=0.55, use_colnames=True)

frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.675676                    (BAKING SET 9 PIECE RETROSPOT )
# 1   0.567568                  (GREEN REGENCY TEACUP AND SAUCER)
# 2   0.675676                           (JAM MAKING SET PRINTED)
# 3   0.702703                         (JAM MAKING SET WITH JARS)
# 4   0.567568                  (PACK OF 72 RETROSPOT CAKE CASES)
# 5   0.621622                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 6   0.648649                                          (POSTAGE)
# 7   0.810811                         (REGENCY CAKESTAND 3 TIER)
# 8   0.594595                 (RETROSPOT TEA SET CERAMIC 11 PC )
# 9   0.567568                 (ROSES REGENCY TEACUP AND SAUCER )
# 10  0.621622              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 11  0.594595                (SET OF 3 CAKE TINS PANTRY DESIGN )
# 12  0.648649                       (SET OF 3 REGENCY CAKE TINS)
# 13  0.567568  (JAM MAKING SET WITH JARS, BAKING SET 9 PIECE ...
# 14  0.621622  (REGENCY CAKESTAND 3 TIER, BAKING SET 9 PIECE ...
# 15  0.567568  (BAKING SET 9 PIECE RETROSPOT , SET OF 3 REGEN...
# 16  0.567568  (GREEN REGENCY TEACUP AND SAUCER, REGENCY CAKE...
# 17  0.567568  (JAM MAKING SET PRINTED, JAM MAKING SET WITH J...
# 18  0.594595  (REGENCY CAKESTAND 3 TIER, JAM MAKING SET WITH...
# 19  0.567568  (RETROSPOT TEA SET CERAMIC 11 PC , REGENCY CAK...
# 20  0.567568  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 21  0.567568  (REGENCY CAKESTAND 3 TIER, SET OF 3 REGENCY CA...

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.55)
# Out:
#                            antecedents                         consequents  \
# 0           (JAM MAKING SET WITH JARS)     (BAKING SET 9 PIECE RETROSPOT )
# 1      (BAKING SET 9 PIECE RETROSPOT )          (JAM MAKING SET WITH JARS)
# 2           (REGENCY CAKESTAND 3 TIER)     (BAKING SET 9 PIECE RETROSPOT )
# 3      (BAKING SET 9 PIECE RETROSPOT )          (REGENCY CAKESTAND 3 TIER)
# 4      (BAKING SET 9 PIECE RETROSPOT )        (SET OF 3 REGENCY CAKE TINS)
# 5         (SET OF 3 REGENCY CAKE TINS)     (BAKING SET 9 PIECE RETROSPOT )
# 6    (GREEN REGENCY TEACUP AND SAUCER)          (REGENCY CAKESTAND 3 TIER)
# 7           (REGENCY CAKESTAND 3 TIER)   (GREEN REGENCY TEACUP AND SAUCER)
# 8             (JAM MAKING SET PRINTED)          (JAM MAKING SET WITH JARS)
# 9           (JAM MAKING SET WITH JARS)            (JAM MAKING SET PRINTED)
# 10          (REGENCY CAKESTAND 3 TIER)          (JAM MAKING SET WITH JARS)
# 11          (JAM MAKING SET WITH JARS)          (REGENCY CAKESTAND 3 TIER)
# 12  (RETROSPOT TEA SET CERAMIC 11 PC )          (REGENCY CAKESTAND 3 TIER)
# 13          (REGENCY CAKESTAND 3 TIER)  (RETROSPOT TEA SET CERAMIC 11 PC )
# 14          (REGENCY CAKESTAND 3 TIER)  (ROSES REGENCY TEACUP AND SAUCER )
# 15  (ROSES REGENCY TEACUP AND SAUCER )          (REGENCY CAKESTAND 3 TIER)
# 16          (REGENCY CAKESTAND 3 TIER)        (SET OF 3 REGENCY CAKE TINS)
# 17        (SET OF 3 REGENCY CAKE TINS)          (REGENCY CAKESTAND 3 TIER)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.702703            0.675676  0.567568    0.807692  1.195385
# 1             0.675676            0.702703  0.567568    0.840000  1.195385
# 2             0.810811            0.675676  0.621622    0.766667  1.134667
# 3             0.675676            0.810811  0.621622    0.920000  1.134667
# 4             0.675676            0.648649  0.567568    0.840000  1.295000
# 5             0.648649            0.675676  0.567568    0.875000  1.295000
# 6             0.567568            0.810811  0.567568    1.000000  1.233333
# 7             0.810811            0.567568  0.567568    0.700000  1.233333
# 8             0.675676            0.702703  0.567568    0.840000  1.195385
# 9             0.702703            0.675676  0.567568    0.807692  1.195385
# 10            0.810811            0.702703  0.594595    0.733333  1.043590
# 11            0.702703            0.810811  0.594595    0.846154  1.043590
# 12            0.594595            0.810811  0.567568    0.954545  1.177273
# 13            0.810811            0.594595  0.567568    0.700000  1.177273
# 14            0.810811            0.567568  0.567568    0.700000  1.233333
# 15            0.567568            0.810811  0.567568    1.000000  1.233333
# 16            0.810811            0.648649  0.567568    0.700000  1.079167
# 17            0.648649            0.810811  0.567568    0.875000  1.079167
#
#     leverage  conviction
# 0   0.092768    1.686486
# 1   0.092768    1.858108
# 2   0.073776    1.389961
# 3   0.073776    2.364865
# 4   0.129291    2.195946
# 5   0.129291    2.594595
# 6   0.107378         inf
# 7   0.107378    1.441441
# 8   0.092768    1.858108
# 9   0.092768    1.686486
# 10  0.024836    1.114865
# 11  0.024836    1.229730
# 12  0.085464    4.162162
# 13  0.085464    1.351351
# 14  0.107378    1.441441
# 15  0.107378         inf
# 16  0.041636    1.171171
# 17  0.041636    1.513514
