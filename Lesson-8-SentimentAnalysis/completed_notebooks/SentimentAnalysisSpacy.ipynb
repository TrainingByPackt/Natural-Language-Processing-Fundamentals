# %% [markdown]
# # Sentiment Analysis

# %%
import plac

# %%
from spacy_examples import SentimentAnalyser
# Out:
# Using TensorFlow backend.
# C:\Users\dwight\Anaconda3\envs\packt\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\Users\dwight\Anaconda3\envs\packt\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
from pathlib import Path

# %%
DATA_DIR = Path('data')
SENTIMENT_DATA_DIR = DATA_DIR / 'sentiment labelled sentences'

# %%
list(SENTIMENT_DATA_DIR.glob('*'))
# Out:
# [WindowsPath('data/sentiment labelled sentences/sentiment labelled sentences'),
#  WindowsPath('data/sentiment labelled sentences/__MACOSX')]

# %%
IMDB_DATA = SENTIMENT_DATA_DIR / 'imdb_labelled.txt'

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100)

# %%
imdb_data = pd.read_table(str(IMDB_DATA), names=['Text', 'Label'])

# %%
imdb_data
# Out:
#                                                                                                     Text  \
# 0                A very, very, very slow-moving, aimless movie about a distressed, drifting young man.
# 1    Not sure who was more lost - the flat characters or the audience, nearly half of whom walked out.
# 2    Attempting artiness with black & white and clever camera angles, the movie disappointed - became...
# 3                                                           Very little music or anything to speak of.
# 4    The best scene in the movie was when Gerardo is trying to find a song that keeps running through...
# 5    The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess bec...
# 6                                                                                    Wasted two hours.
# 7                        Saw the movie today and thought it was a good effort, good messages for kids.
# ...

# %%
from gensim.preprocessing.text import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d0c052e9fe3b> in <module>
# ----> 1 from gensim.preprocessing.text import *
#
# ModuleNotFoundError: No module named 'gensim.preprocessing'
